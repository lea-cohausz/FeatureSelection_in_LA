# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
from scipy.io import arff
from preprocesing import preprcoess_sap, data_summary
from experiment_sap import experiment_sap
# Out:
# WARNING:root:No module named 'inFairness': SenSeI and SenSR will be unavailable. To install, run:
# pip install 'aif360[inFairness]'

# %%
arff_file = arff.loadarff('Sapfile1.arff')
data = pd.DataFrame(arff_file[0])
data = data.select_dtypes([object])
data = data.stack().str.decode('utf-8').unstack()
data.head()
# Out:
#   ge   cst   tnp   twp iap   esp arr         ms ls    as  ...  fq  mq  \
# 0  F     G  Good  Good  Vg  Good   Y  Unmarried  V  Paid  ...  Um  10
# 1  M   OBC    Vg    Vg  Vg    Vg   N  Unmarried  V  Paid  ...  Um  Il
# 2  F   OBC  Good  Good  Vg  Good   N  Unmarried  V  Paid  ...  12  10
# 3  M  MOBC  Pass  Good  Vg  Good   N  Unmarried  V  Paid  ...  12  Um
# 4  M     G  Good  Good  Vg    Vg   N  Unmarried  V  Paid  ...  10  12
#
#          fo         mo       nf       sh       ss   me       tt      atd
# 0    Farmer  Housewife    Large     Poor     Govt  Asm    Small     Good
# 1   Service    Service    Small     Poor     Govt  Asm  Average  Average
# 2   Service  Housewife  Average  Average     Govt  Asm    Large     Good
# 3  Business   Business    Large     Poor     Govt  Asm  Average  Average
# 4   Service  Housewife    Large     Poor  Private  Asm    Small     Good
#
# [5 rows x 22 columns]

# %%
data = preprcoess_sap(data)
data.head()
# Out:
#    ge  tnp  twp  iap  target  arr  ls  as  fmi  fs  ...  fo_Service  \
# 0   0    1    1    2       1    0   0   0    1   1  ...           0
# 1   1    2    2    2       2    1   0   0    0   1  ...           1
# 2   0    1    1    2       1    1   0   0    2   1  ...           1
# 3   1    0    1    2       1    1   0   0    1   0  ...           0
# 4   1    1    1    2       2    1   0   0    2   1  ...           1
#
#    mo_Business  mo_Housewife  mo_Others  mo_Retired  mo_Service  me_Asm  \
# 0            0             1          0           0           0       1
# 1            0             0          0           0           1       1
# 2            0             1          0           0           0       1
# 3            1             0          0           0           0       1
# 4            0             1          0           0           0       1
#
#    me_Ben  me_Eng  me_Hin
# 0       0       0       0
# 1       0       0       0
# 2       0       0       0
# 3       0       0       0
# 4       0       0       0
#
# [5 rows x 37 columns]

# %%
results = experiment_sap(data, n_splits=5, random_state=42)

rows = []
for fs_method, models in results.items():
    for model_name, metrics in models.items():
        row = {
            "Feature_Selector": fs_method,
            "Model": model_name,
            "F1_with_FS": metrics["mean_f1_with_fs"],
            "F1_without_FS": metrics["mean_f1_without_fs"],
            "Abs_Diff": metrics["mean_abs_diff"],
            "Mean_DPR_with_FS": metrics["demographic_parity_ratio_fs"],
            "Mean_EOR_with_FS": metrics["equalized_odds_ratio_fs"],
            "Mean_DPR_without_FS": metrics["demographic_parity_ratio_no_fs"],
            "Mean_EOR_without_FS": metrics["equalized_odds_ratio_no_fs"],
            "Num_Features": metrics["num_features"],
        }
        rows.append(row)

df = pd.DataFrame(rows)

# Optional: round values for nicer display
df[["F1_with_FS", "F1_without_FS", "Abs_Diff", "Mean_DPR_with_FS", "Mean_EOR_with_FS", "Mean_DPR_without_FS", "Mean_EOR_without_FS", "Num_Features"]] = df[["F1_with_FS", "F1_without_FS", "Abs_Diff", "Mean_DPR_with_FS", "Mean_EOR_with_FS", "Mean_DPR_without_FS", "Mean_EOR_without_FS", "Num_Features"]].round(4)
df.to_csv("Results_Paper.csv", index=False)
# Display the DataFrame
print(df)
# Out:
# Fold 1/5...
# I ran through RandomForest
# I ran through XGBoost
# I ran through kNN
# I ran through SVM
# I ran through MLP
# I ran through LR
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'ge': 'N', 'tnp': 'N', 'twp': 'N', 'iap': 'N', 'target': 'N', 'arr': 'N', 'ls': 'N', 'as': 'N', 'fmi': 'N', 'fs': 'N', 'fq': 'N', 'mq': 'N', 'nf': 'N', 'sh': 'N', 'ss': 'N', 'tt': 'N', 'atd': 'N', 'cst_G': 'N', 'cst_MOBC': 'N', 'cst_OBC': 'N', 'cst_SC': 'N', 'cst_ST': 'N', 'ms_Unmarried': 'N', 'fo_Business': 'N', 'fo_Farmer': 'N', 'fo_Others': 'N', 'fo_Retired': 'N', 'fo_Service': 'N', 'mo_Business': 'N', 'mo_Housewife': 'N', 'mo_Others': 'N', 'mo_Retired': 'N', 'mo_Service': 'N', 'me_Asm': 'N', 'me_Ben': 'N', 'me_Eng': 'N', 'me_Hin': 'N'}
# I ran through CatBoost
# Working for n conditional variables: 4:  80%|████████  | 4/5 [00:02<00:00,  1.72it/s]
# I ran through mb_exdesc_iamb, RandomForest
# I ran through mb_exdesc_iamb, XGBoost
# I ran through mb_exdesc_iamb, kNN
# I ran through mb_exdesc_iamb, SVM
# I ran through mb_exdesc_iamb, MLP
# I ran through mb_exdesc_iamb, LR
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'ge': 'N', 'tnp': 'N', 'twp': 'N', 'iap': 'N', 'target': 'N', 'arr': 'N', 'ls': 'N', 'as': 'N', 'fmi': 'N', 'fs': 'N', 'fq': 'N', 'mq': 'N', 'nf': 'N', 'sh': 'N', 'ss': 'N', 'tt': 'N', 'atd': 'N', 'cst_G': 'N', 'cst_MOBC': 'N', 'cst_OBC': 'N', 'cst_SC': 'N', 'cst_ST': 'N', 'ms_Unmarried': 'N', 'fo_Business': 'N', 'fo_Farmer': 'N', 'fo_Others': 'N', 'fo_Retired': 'N', 'fo_Service': 'N', 'mo_Business': 'N', 'mo_Housewife': 'N', 'mo_Others': 'N', 'mo_Retired': 'N', 'mo_Service': 'N', 'me_Asm': 'N', 'me_Ben': 'N', 'me_Eng': 'N', 'me_Hin': 'N'}
# I ran through mb_exdesc_iamb, CatBoost
# Working for n conditional variables: 4:  80%|████████  | 4/5 [00:00<00:00, 22.79it/s]
# I ran through exdesc_iamb, RandomForest
# I ran through exdesc_iamb, XGBoost
# I ran through exdesc_iamb, kNN
# I ran through exdesc_iamb, SVM
# I ran through exdesc_iamb, MLP
# I ran through exdesc_iamb, LR
# I ran through exdesc_iamb, CatBoost
#
# Fold 2/5...
# I ran through RandomForest
# I ran through XGBoost
# I ran through kNN
# I ran through SVM
# I ran through MLP
# I ran through LR
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'ge': 'N', 'tnp': 'N', 'twp': 'N', 'iap': 'N', 'target': 'N', 'arr': 'N', 'ls': 'N', 'as': 'N', 'fmi': 'N', 'fs': 'N', 'fq': 'N', 'mq': 'N', 'nf': 'N', 'sh': 'N', 'ss': 'N', 'tt': 'N', 'atd': 'N', 'cst_G': 'N', 'cst_MOBC': 'N', 'cst_OBC': 'N', 'cst_SC': 'N', 'cst_ST': 'N', 'ms_Unmarried': 'N', 'fo_Business': 'N', 'fo_Farmer': 'N', 'fo_Others': 'N', 'fo_Retired': 'N', 'fo_Service': 'N', 'mo_Business': 'N', 'mo_Housewife': 'N', 'mo_Others': 'N', 'mo_Retired': 'N', 'mo_Service': 'N', 'me_Asm': 'N', 'me_Ben': 'N', 'me_Eng': 'N', 'me_Hin': 'N'}
# I ran through CatBoost
# Working for n conditional variables: 4:  80%|████████  | 4/5 [00:00<00:00, 21.87it/s]
# I ran through mb_exdesc_iamb, RandomForest
# I ran through mb_exdesc_iamb, XGBoost
# I ran through mb_exdesc_iamb, kNN
# I ran through mb_exdesc_iamb, SVM
# I ran through mb_exdesc_iamb, MLP
# I ran through mb_exdesc_iamb, LR
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'ge': 'N', 'tnp': 'N', 'twp': 'N', 'iap': 'N', 'target': 'N', 'arr': 'N', 'ls': 'N', 'as': 'N', 'fmi': 'N', 'fs': 'N', 'fq': 'N', 'mq': 'N', 'nf': 'N', 'sh': 'N', 'ss': 'N', 'tt': 'N', 'atd': 'N', 'cst_G': 'N', 'cst_MOBC': 'N', 'cst_OBC': 'N', 'cst_SC': 'N', 'cst_ST': 'N', 'ms_Unmarried': 'N', 'fo_Business': 'N', 'fo_Farmer': 'N', 'fo_Others': 'N', 'fo_Retired': 'N', 'fo_Service': 'N', 'mo_Business': 'N', 'mo_Housewife': 'N', 'mo_Others': 'N', 'mo_Retired': 'N', 'mo_Service': 'N', 'me_Asm': 'N', 'me_Ben': 'N', 'me_Eng': 'N', 'me_Hin': 'N'}
# I ran through mb_exdesc_iamb, CatBoost
# Working for n conditional variables: 4:  80%|████████  | 4/5 [00:00<00:00, 20.93it/s]
# I ran through exdesc_iamb, RandomForest
# I ran through exdesc_iamb, XGBoost
# I ran through exdesc_iamb, kNN
# I ran through exdesc_iamb, SVM
# I ran through exdesc_iamb, MLP
# I ran through exdesc_iamb, LR
# I ran through exdesc_iamb, CatBoost
#
# Fold 3/5...
# I ran through RandomForest
# I ran through XGBoost
# I ran through kNN
# I ran through SVM
# I ran through MLP
# I ran through LR
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'ge': 'N', 'tnp': 'N', 'twp': 'N', 'iap': 'N', 'target': 'N', 'arr': 'N', 'ls': 'N', 'as': 'N', 'fmi': 'N', 'fs': 'N', 'fq': 'N', 'mq': 'N', 'nf': 'N', 'sh': 'N', 'ss': 'N', 'tt': 'N', 'atd': 'N', 'cst_G': 'N', 'cst_MOBC': 'N', 'cst_OBC': 'N', 'cst_SC': 'N', 'cst_ST': 'N', 'ms_Unmarried': 'N', 'fo_Business': 'N', 'fo_Farmer': 'N', 'fo_Others': 'N', 'fo_Retired': 'N', 'fo_Service': 'N', 'mo_Business': 'N', 'mo_Housewife': 'N', 'mo_Others': 'N', 'mo_Retired': 'N', 'mo_Service': 'N', 'me_Asm': 'N', 'me_Ben': 'N', 'me_Eng': 'N', 'me_Hin': 'N'}
# I ran through CatBoost
# Working for n conditional variables: 4:  80%|████████  | 4/5 [00:00<00:00, 20.24it/s]
# I ran through mb_exdesc_iamb, RandomForest
# I ran through mb_exdesc_iamb, XGBoost
# I ran through mb_exdesc_iamb, kNN
# I ran through mb_exdesc_iamb, SVM
# I ran through mb_exdesc_iamb, MLP
# I ran through mb_exdesc_iamb, LR
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'ge': 'N', 'tnp': 'N', 'twp': 'N', 'iap': 'N', 'target': 'N', 'arr': 'N', 'ls': 'N', 'as': 'N', 'fmi': 'N', 'fs': 'N', 'fq': 'N', 'mq': 'N', 'nf': 'N', 'sh': 'N', 'ss': 'N', 'tt': 'N', 'atd': 'N', 'cst_G': 'N', 'cst_MOBC': 'N', 'cst_OBC': 'N', 'cst_SC': 'N', 'cst_ST': 'N', 'ms_Unmarried': 'N', 'fo_Business': 'N', 'fo_Farmer': 'N', 'fo_Others': 'N', 'fo_Retired': 'N', 'fo_Service': 'N', 'mo_Business': 'N', 'mo_Housewife': 'N', 'mo_Others': 'N', 'mo_Retired': 'N', 'mo_Service': 'N', 'me_Asm': 'N', 'me_Ben': 'N', 'me_Eng': 'N', 'me_Hin': 'N'}
# I ran through mb_exdesc_iamb, CatBoost
# Working for n conditional variables: 4:  80%|████████  | 4/5 [00:00<00:00, 22.62it/s]
# I ran through exdesc_iamb, RandomForest
# I ran through exdesc_iamb, XGBoost
# I ran through exdesc_iamb, kNN
# I ran through exdesc_iamb, SVM
# I ran through exdesc_iamb, MLP
# I ran through exdesc_iamb, LR
# I ran through exdesc_iamb, CatBoost
#
# Fold 4/5...
# I ran through RandomForest
# I ran through XGBoost
# I ran through kNN
# I ran through SVM
# I ran through MLP
# I ran through LR
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'ge': 'N', 'tnp': 'N', 'twp': 'N', 'iap': 'N', 'target': 'N', 'arr': 'N', 'ls': 'N', 'as': 'N', 'fmi': 'N', 'fs': 'N', 'fq': 'N', 'mq': 'N', 'nf': 'N', 'sh': 'N', 'ss': 'N', 'tt': 'N', 'atd': 'N', 'cst_G': 'N', 'cst_MOBC': 'N', 'cst_OBC': 'N', 'cst_SC': 'N', 'cst_ST': 'N', 'ms_Unmarried': 'N', 'fo_Business': 'N', 'fo_Farmer': 'N', 'fo_Others': 'N', 'fo_Retired': 'N', 'fo_Service': 'N', 'mo_Business': 'N', 'mo_Housewife': 'N', 'mo_Others': 'N', 'mo_Retired': 'N', 'mo_Service': 'N', 'me_Asm': 'N', 'me_Ben': 'N', 'me_Eng': 'N', 'me_Hin': 'N'}
# I ran through CatBoost
# Working for n conditional variables: 4:  80%|████████  | 4/5 [00:00<00:00, 22.81it/s]
# I ran through mb_exdesc_iamb, RandomForest
# I ran through mb_exdesc_iamb, XGBoost
# I ran through mb_exdesc_iamb, kNN
# I ran through mb_exdesc_iamb, SVM
# I ran through mb_exdesc_iamb, MLP
# I ran through mb_exdesc_iamb, LR
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'ge': 'N', 'tnp': 'N', 'twp': 'N', 'iap': 'N', 'target': 'N', 'arr': 'N', 'ls': 'N', 'as': 'N', 'fmi': 'N', 'fs': 'N', 'fq': 'N', 'mq': 'N', 'nf': 'N', 'sh': 'N', 'ss': 'N', 'tt': 'N', 'atd': 'N', 'cst_G': 'N', 'cst_MOBC': 'N', 'cst_OBC': 'N', 'cst_SC': 'N', 'cst_ST': 'N', 'ms_Unmarried': 'N', 'fo_Business': 'N', 'fo_Farmer': 'N', 'fo_Others': 'N', 'fo_Retired': 'N', 'fo_Service': 'N', 'mo_Business': 'N', 'mo_Housewife': 'N', 'mo_Others': 'N', 'mo_Retired': 'N', 'mo_Service': 'N', 'me_Asm': 'N', 'me_Ben': 'N', 'me_Eng': 'N', 'me_Hin': 'N'}
# I ran through mb_exdesc_iamb, CatBoost
# Working for n conditional variables: 4:  80%|████████  | 4/5 [00:00<00:00, 22.36it/s]
# I ran through exdesc_iamb, RandomForest
# I ran through exdesc_iamb, XGBoost
# I ran through exdesc_iamb, kNN
# I ran through exdesc_iamb, SVM
# I ran through exdesc_iamb, MLP
# I ran through exdesc_iamb, LR
# I ran through exdesc_iamb, CatBoost
#
# Fold 5/5...
# I ran through RandomForest
# I ran through XGBoost
# I ran through kNN
# I ran through SVM
# I ran through MLP
# I ran through LR
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'ge': 'N', 'tnp': 'N', 'twp': 'N', 'iap': 'N', 'target': 'N', 'arr': 'N', 'ls': 'N', 'as': 'N', 'fmi': 'N', 'fs': 'N', 'fq': 'N', 'mq': 'N', 'nf': 'N', 'sh': 'N', 'ss': 'N', 'tt': 'N', 'atd': 'N', 'cst_G': 'N', 'cst_MOBC': 'N', 'cst_OBC': 'N', 'cst_SC': 'N', 'cst_ST': 'N', 'ms_Unmarried': 'N', 'fo_Business': 'N', 'fo_Farmer': 'N', 'fo_Others': 'N', 'fo_Retired': 'N', 'fo_Service': 'N', 'mo_Business': 'N', 'mo_Housewife': 'N', 'mo_Others': 'N', 'mo_Retired': 'N', 'mo_Service': 'N', 'me_Asm': 'N', 'me_Ben': 'N', 'me_Eng': 'N', 'me_Hin': 'N'}
# I ran through CatBoost
# Working for n conditional variables: 4:  80%|████████  | 4/5 [00:00<00:00, 23.22it/s]
# I ran through mb_exdesc_iamb, RandomForest
# I ran through mb_exdesc_iamb, XGBoost
# I ran through mb_exdesc_iamb, kNN
# I ran through mb_exdesc_iamb, SVM
# I ran through mb_exdesc_iamb, MLP
# I ran through mb_exdesc_iamb, LR
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'ge': 'N', 'tnp': 'N', 'twp': 'N', 'iap': 'N', 'target': 'N', 'arr': 'N', 'ls': 'N', 'as': 'N', 'fmi': 'N', 'fs': 'N', 'fq': 'N', 'mq': 'N', 'nf': 'N', 'sh': 'N', 'ss': 'N', 'tt': 'N', 'atd': 'N', 'cst_G': 'N', 'cst_MOBC': 'N', 'cst_OBC': 'N', 'cst_SC': 'N', 'cst_ST': 'N', 'ms_Unmarried': 'N', 'fo_Business': 'N', 'fo_Farmer': 'N', 'fo_Others': 'N', 'fo_Retired': 'N', 'fo_Service': 'N', 'mo_Business': 'N', 'mo_Housewife': 'N', 'mo_Others': 'N', 'mo_Retired': 'N', 'mo_Service': 'N', 'me_Asm': 'N', 'me_Ben': 'N', 'me_Eng': 'N', 'me_Hin': 'N'}
# I ran through mb_exdesc_iamb, CatBoost
# Working for n conditional variables: 4:  80%|████████  | 4/5 [00:00<00:00, 21.26it/s]
# I ran through exdesc_iamb, RandomForest
# I ran through exdesc_iamb, XGBoost
# I ran through exdesc_iamb, kNN
# I ran through exdesc_iamb, SVM
# I ran through exdesc_iamb, MLP
# I ran through exdesc_iamb, LR
# I ran through exdesc_iamb, CatBoost
#    Feature_Selector         Model  F1_with_FS  F1_without_FS  Abs_Diff  \
# 0    mb_exdesc_iamb  RandomForest      0.5061         0.5000    0.1072
# 1    mb_exdesc_iamb       XGBoost      0.6011         0.5764    0.0425
# 2    mb_exdesc_iamb           kNN      0.6582         0.4695    0.2373
# 3    mb_exdesc_iamb           SVM      0.5351         0.4490    0.1251
# 4    mb_exdesc_iamb           MLP      0.4643         0.5219    0.0912
# 5    mb_exdesc_iamb            LR      0.5290         0.5300    0.1347
# 6    mb_exdesc_iamb      CatBoost      0.5791         0.5980    0.0881
# 7       exdesc_iamb  RandomForest      0.5000         0.5000    0.0000
# 8       exdesc_iamb       XGBoost      0.5764         0.5764    0.0000
# 9       exdesc_iamb           kNN      0.4695         0.4695    0.0000
# 10      exdesc_iamb           SVM      0.4490         0.4490    0.0000
# 11      exdesc_iamb           MLP      0.5219         0.5219    0.0000
# 12      exdesc_iamb            LR      0.5300         0.5300    0.0000
# 13      exdesc_iamb      CatBoost      0.5980         0.5980    0.0000
#
#     Mean_DPR_with_FS  Mean_EOR_with_FS  Mean_DPR_without_FS  \
# 0             0.5268               NaN                  NaN
# 1             0.4427            0.2031                  NaN
# 2             0.3876               NaN                  NaN
# 3             0.5139            0.2877                  NaN
# 4             0.6880            0.4990                  NaN
# 5             0.5148               NaN               0.4855
# 6             0.4561               NaN                  NaN
# 7             0.5443               NaN                  NaN
# 8             0.5342            0.3936                  NaN
# 9             0.5508               NaN                  NaN
# 10            0.6207            0.4799                  NaN
# 11            0.5021               NaN                  NaN
# 12            0.4855               NaN               0.4855
# 13            0.4796               NaN                  NaN
#
#     Mean_EOR_without_FS  Num_Features
# 0                   NaN           3.0
# 1                   NaN           3.0
# 2                   NaN           3.0
# 3                   NaN           3.0
# 4                   NaN           3.0
# 5                   NaN           3.0
# 6                   NaN           3.0
# 7                   NaN          36.0
# 8                   NaN          36.0
# 9                   NaN          36.0
# 10                  NaN          36.0
# 11                  NaN          36.0
# 12                  NaN          36.0
# 13                  NaN          36.0
